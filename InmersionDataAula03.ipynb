# %% [markdown]
# <a href="https://colab.research.google.com/github/KeneQuirosM/DataInmersion_Aula_03/blob/main/InmersionDataAula03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**Aula 2**

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
#import desde drive del csv a usar
inmuebles = pd.read_csv('/content/drive/MyDrive/DataInmersion/inmuebles_bogota.csv')
inmuebles.sample(8)
# Out:
#              Tipo                                  Descripcion  Habitaciones  \
# 1105  Apartamento  Apartamento en venta en Nicolas De Federman             3
# 8578  Apartamento            Apartamento en venta en Chapinero             3
# 8459  Apartamento   Apartamento en venta en Zona Noroccidental             2
# 3359  Apartamento    Apartamento en venta en Villas De Granada             3
# 949   Apartamento         Apartamento en venta en San Patricio             2
# 6039  Apartamento   Apartamento en venta en Zona Noroccidental             3
# 2570  Apartamento          Apartamento en venta en Los Rosales             2
# 3001  Apartamento          Apartamento en venta en Los Rosales             5
#
#       Baños  Área               Barrio                                    UPZ  \
# 1105      2   122  Nicolas De Federman                            Teusaquillo
# 8578      5   185            Chapinero     CHAPINERO: Pardo Rubio + Chapinero
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.Valor[0]
# Out:
# '$ 360.000.000'

# %%
#tratamiento para poder sumar la columna valor
inmuebles.Valor[0].split()
# Out:
# ['$', '360.000.000']

# %%
valor = inmuebles.Valor.str.split(expand=True)
inmuebles['Moneda'] = valor[0]
inmuebles['Precio'] = valor[1]
inmuebles.sample(3)
# Out:
#              Tipo                       Descripcion  Habitaciones  Baños  \
# 813   Apartamento   Apartamento en venta en Kennedy             2      1
# 9129  Apartamento  Apartamento en venta en Cedritos             1      2
# 5276  Apartamento      Apartamento en venta en Bosa             3      1
#
#       Área    Barrio              UPZ          Valor Moneda       Precio
# 813     55   Kennedy  Kennedy Central  $ 220.000.000      $  220.000.000
# 9129    54  Cedritos          Usaquén  $ 350.000.000      $  350.000.000
# 5276    47      Bosa     Bosa Central  $ 128.000.000      $  128.000.000

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Baños         9520 non-null   int64
#  4   Área          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
#  8   Moneda        9520 non-null   object
#  9   Precio        9520 non-null   object
# dtypes: int64(3), object(7)
# memory usage: 743.9+ KB

# %%
inmuebles['Precio'] = inmuebles['Precio'].str.replace('.','',regex=True)

# %%
inmuebles[['Precio','Barrio']]
# Out:
#           Precio                  Barrio
# 0      360000000      Zona Noroccidental
# 1      670000000                Castilla
# 2     1120000000         Chico Reservado
# 3      890000000                 Usaquén
# 4      970000000             Bella Suiza
# ...          ...                     ...
# 9515   290000000                 Kennedy
# 9516   670000000  Parque Central Bavaria
# 9517   900000000                Restrepo
# 9518   335000000                Engativa
# 9519   144990000                 Tintala
#
# [9520 rows x 2 columns]

# %%
inmuebles['Precio_Millon'] = inmuebles.Precio.astype('float')/1000000
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Tipo           9520 non-null   object
#  1   Descripcion    9520 non-null   object
#  2   Habitaciones   9520 non-null   int64
#  3   Baños          9520 non-null   int64
#  4   Área           9520 non-null   int64
#  5   Barrio         9520 non-null   object
#  6   UPZ            9478 non-null   object
#  7   Valor          9520 non-null   object
#  8   Moneda         9520 non-null   object
#  9   Precio         9520 non-null   object
#  10  Precio_Millon  9520 non-null   float64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 818.2+ KB

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Baños           Área  Precio_Millon
# count   9520.000000  9520.000000    9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706     602.062354
# std        2.049856     1.255314    1731.379622     704.602062
# min        1.000000     0.000000       2.000000      60.000000
# 25%        2.000000     2.000000      57.000000     250.000000
# 50%        3.000000     2.000000      80.000000     409.182500
# 75%        3.000000     3.000000     135.000000     680.000000
# max      110.000000     9.000000  166243.000000   16000.000000

# %%
pd.set_option('display.precision',2)
pd.describe_option('display.float_format',lambda x: '%.2f' % x)
inmuebles.describe()
# Out:
# display.float_format : callable
#     The callable should accept a floating point number and return
#     a string with the desired format of the number. This is used
#     in some places like SeriesFormatter.
#     See formats.format.EngFormatter for an example.
#     [default: None] [currently: None]
#        Habitaciones    Baños       Área  Precio_Millon
# count       9520.00  9520.00    9520.00        9520.00
# mean           3.07     2.45     146.66         602.06
# std            2.05     1.26    1731.38         704.60
# min            1.00     0.00       2.00          60.00
# 25%            2.00     2.00      57.00         250.00
# 50%            3.00     2.00      80.00         409.18
# 75%            3.00     3.00     135.00         680.00
# max          110.00     9.00  166243.00       16000.00

# %%
inmuebles.loc[inmuebles.Habitaciones == 110] #Localizar un dato
# Out:
#      Tipo                Descripcion  Habitaciones  Baños  Área    Barrio  \
# 897  Casa  Casa en venta en La Uribe           110      2   110  La Uribe
#
#          UPZ          Valor Moneda     Precio  Precio_Millon
# 897  Usaquén  $ 480.000.000      $  480000000          480.0

# %%
inmuebles['Precio_Millon'].plot.hist(bins=100)
# Out:
# <Axes: ylabel='Frequency'>

# %%
#seaborn para visualizar datos estadisticos mas detallados

import matplotlib.pyplot as plt #otra lib para estadistica
import seaborn as sns

plt.figure(figsize=(10,6)) #definir tamanio del lienzo
grafica = sns.histplot(data=inmuebles, x='Precio_Millon',kde=True, hue='Tipo')
grafica.set_title('Distribucion de valores de los inmuebles en Bogota')
plt.xlim((50,1000))
plt.savefig('/content/drive/MyDrive/DataInmersion/valor_inmuebles_bogota.png',format='png')
plt.show()

# %% [markdown]
# **Desafio**
#
#
#
# 1.   Estudiar mejor el histograma de valores , seleccionar 3 tipos de inmuebles
# 2.   Precio dek=l metro 2 por barrio y usar el mejor grafico para reresentar mejor esta variable

# %% [markdown]
# #**Aula 3**

# %%
columnas = {'Baños':'Banos', 'Área':'Area' }
#renombrar columnas en las que el acento puede llegar afectar

inmuebles = inmuebles.rename(columns=columnas)
inmuebles['Valor_m2_millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
inmuebles.head(3)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-f7d428faaaac> in <cell line: 4>()
#       2 #renombrar columnas en las que el acento puede llegar afectar
#       3
# ----> 4 inmuebles = inmuebles.rename(columns=columnas)
#       5 inmuebles['Valor_m2_millon'] = inmuebles['Precio_Millon']/inmuebles['Area']
#       6 inmuebles.head(3)
#
# NameError: name 'inmuebles' is not defined

# %%
inmuebles.groupby('Barrio').mean()
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                     3.00   2.00   97.00         580.00
# Alhambra                    3.00   2.94  190.41         752.35
# Andes Norte                 3.00   2.86  124.86         709.57
# Antonio Nariño              4.31   2.50  163.06         459.22
# Barrancas                   2.87   2.13   70.20         314.13
# ...                          ...    ...     ...            ...
# Villa Maria                 4.69   3.69  207.15         402.85
# Villas De Granada           3.45   2.32   86.59         282.30
# Villemar                    2.94   2.06   76.89         303.83
# Zona Franca                 2.00   1.00   54.00         160.00
# Zona Noroccidental          3.17   2.51  135.79         620.81
#
#                     Valor_m2_millon
# Barrio
# Alameda                        5.98
# Alhambra                       4.33
# Andes Norte                    6.05
# Antonio Nariño                 3.53
# ...

# %%
datos_barrio = inmuebles.groupby('Barrio').sum()
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_millon
# Barrio
# Alameda                        5.98
# Alhambra                      73.56
# Andes Norte                   42.35
# Antonio Nariño               169.47
# ...

# %%
datos_barrio['Valor_m2_barrio'] = datos_barrio['Precio_Millon']/datos_barrio['Area']
datos_barrio
# Out:
#                     Habitaciones  Banos    Area  Precio_Millon  \
# Barrio
# Alameda                        3      2      97         580.00
# Alhambra                      51     50    3237       12790.00
# Andes Norte                   21     20     874        4967.00
# Antonio Nariño               207    120    7827       22042.65
# Barrancas                     43     32    1053        4712.00
# ...                          ...    ...     ...            ...
# Villa Maria                   61     48    2693        5237.00
# Villas De Granada             76     51    1905        6210.62
# Villemar                      53     37    1384        5469.00
# Zona Franca                    2      1      54         160.00
# Zona Noroccidental          2778   2204  119084      544453.06
#
#                     Valor_m2_millon  Valor_m2_barrio
# Barrio
# Alameda                        5.98             5.98
# Alhambra                      73.56             3.95
# ...

# %%
m2_barrio = dict(datos_barrio['Valor_m2_barrio'])

# %%
inmuebles['Valor_m2_barrio'] = inmuebles['Barrio']
inmuebles['Valor_m2_barrio'] = inmuebles['Valor_m2_barrio'].map(m2_barrio)
inmuebles.head(5)
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Banos  Area              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor Moneda      Precio  Precio_Millon  Valor_m2_millon  \
# ...

# %%
top_barrios = inmuebles['Barrio'].value_counts()[:10].index

# %%
datos_barrio.reset_index(inplace=True)
datos_barrio
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 0               Alameda             3      2      97         580.00
# 1              Alhambra            51     50    3237       12790.00
# 2           Andes Norte            21     20     874        4967.00
# 3        Antonio Nariño           207    120    7827       22042.65
# 4             Barrancas            43     32    1053        4712.00
# ..                  ...           ...    ...     ...            ...
# 144         Villa Maria            61     48    2693        5237.00
# 145   Villas De Granada            76     51    1905        6210.62
# 146            Villemar            53     37    1384        5469.00
# 147         Zona Franca             2      1      54         160.00
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_millon  Valor_m2_barrio
# 0               5.98             5.98
# 1              73.56             3.95
# ...

# %%
datos_barrio.query('Barrio in @top_barrios')
# Out:
#                  Barrio  Habitaciones  Banos    Area  Precio_Millon  \
# 5        Barrios Unidos          1525   1196   87799      259877.76
# 10                 Bosa          1743    789   34879       93400.56
# 22             Cedritos          1458   1348   53711      270027.73
# 24            Chapinero           892    913   81248      372130.93
# 50             Engativa          1676   1077   59808      172711.73
# 63              Kennedy          2151   1233   61475      207963.65
# 125       Santa Barbara          1073   1162   54693      320097.80
# 132                Suba          1497   1202   61615      266406.04
# 138             Usaquén          3109   3044  148121      837710.36
# 148  Zona Noroccidental          2778   2204  119084      544453.06
#
#      Valor_m2_millon  Valor_m2_barrio
# 5            2070.61             2.96
# 10           1654.36             2.68
# 22           2853.23             5.03
# 24           2466.03             4.58
# ...

# %%
plt.figure(figsize=(10,8))
ax = sns.barplot(x='Barrio',y='Valor_m2_barrio', data = datos_barrio.query('Barrio in @top_barrios'))
ax.tick_params(axis='x',rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_millon', data = inmuebles.query('Barrio in @top_barrios'))
ax.tick_params(axis='x',rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Valor_m2_millon', data = inmuebles.query('Barrio in @top_barrios & Valor_m2_millon < 10'))
ax.tick_params(axis='x',rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Area', data = inmuebles.query('Barrio in @top_barrios  & Area < 500'))
ax.tick_params(axis='x',rotation=45)
plt.show()

# %%
plt.figure(figsize=(10,8))
ax = sns.boxplot(x='Barrio',y='Precio_Millon', data = inmuebles.query('Barrio in @top_barrios  & Precio_Millon < 2000'))
ax.tick_params(axis='x',rotation=45)
plt.show()

# %%
datos_a = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Identificación (Capítulo A).csv' , sep = ';' ,encoding = 'latin-1')
datos_a.head()
# Out:
#    DIRECTORIO  DPTO   MPIO  CLASE  COD_LOCALIDAD NOMBRE_LOCALIDAD  \
# 0   3004346.0    11  11001      1            3.0         Santa Fe
# 1   3004347.0    11  11001      1           14.0     Los Mártires
# 2   3004348.0    11  11001      1            3.0         Santa Fe
# 3   3004349.0    11  11001      1            1.0          Usaquén
# 4   3004350.0    11  11001      1            1.0          Usaquén
#
#    COD_UPZ_GRUPO                        NOMBRE_UPZ_GRUPO  ESTRATO2021  \
# 0          814.0  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 1           37.0                            Santa Isabel     11001162
# 2          814.0  SANTA FE: Las Nieves + Sagrado Corazón     11001187
# 3          803.0   USAQUÉN: Country Club + Santa Bárbara     11001176
# 4          803.0   USAQUÉN: Country Club + Santa Bárbara     11001176
#
#                            NOMBRE_ESTRATO             FEX_C
# 0  SANTA FE: Las Nieves + Sagrado Corazón  13,2266692027239
# ...

# %%
datos_a.shape
# Out:
# (106467, 11)

# %%
datos_a = datos_a.loc[datos_a.MPIO == 11001]
datos_a.shape
# Out:
# (86504, 11)

# %%
datos_b = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Datos de la vivenda y su entorno (Capítulo B).csv' , sep = ';' ,encoding = 'latin-1')
datos_c = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv' , sep = ';' ,encoding = 'latin-1')
datos_e = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Composición del hogar y demografía (Capítulo E).csv' , sep = ';' ,encoding = 'latin-1')
datos_h = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Educación (Capítulo H).csv' , sep = ';' ,encoding = 'latin-1')
datos_l = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Percepción sobre las condiciones de vida y el desempeño institucional (Capítulo L).csv' , sep = ';' ,encoding = 'latin-1')
datos_k = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Fuerza de trabajo (Capítulo K).csv' , sep = ';' ,encoding = 'latin-1')
# Out:
# <ipython-input-10-72fddbb4f872>:2: DtypeWarning: Columns (4,25,30,47) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_c = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Condiciones habitacionales del hogar (Capítulo C).csv' , sep = ';' ,encoding = 'latin-1')
# <ipython-input-10-72fddbb4f872>:3: DtypeWarning: Columns (66) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_e = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Composición del hogar y demografía (Capítulo E).csv' , sep = ';' ,encoding = 'latin-1')
# <ipython-input-10-72fddbb4f872>:4: DtypeWarning: Columns (81) have mixed types. Specify dtype option on import or set low_memory=False.
#   datos_h = pd.read_csv('/content/drive/MyDrive/DataInmersion/archivos-dane/Educación (Capítulo H).csv' , sep = ';' ,encoding = 'latin-1')
# ...

# %%
datos_dane = pd.merge(datos_a,datos_b,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (86504, 73)

# %%
datos_dane = pd.merge(datos_dane,datos_c,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (87061, 214)

# %%
datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-13-a8281422ec17>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'FEX_C_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_e,on='DIRECTORIO', how='left')
# (238559, 281)

# %%
datos_dane = pd.merge(datos_dane,datos_h,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# (783952, 416)

# %%
datos_dane = pd.merge(datos_dane,datos_l,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-64-810c396fd620>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'DIRECTORIO_HOG_x', 'FEX_C_x', 'SECUENCIA_P_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_l,on='DIRECTORIO', how='left')
# (867264, 594)

# %%
datos_dane = pd.merge(datos_dane,datos_k,on='DIRECTORIO', how='left')
datos_dane.shape
# Out:
# <ipython-input-15-e7340c008984>:1: FutureWarning: Passing 'suffixes' which cause duplicate columns {'SECUENCIA_P_x', 'FEX_C_x', 'DIRECTORIO_HOG_x'} in the result is deprecated and will raise a MergeError in a future version.
#   datos_dane = pd.merge(datos_dane,datos_k,on='DIRECTORIO', how='left')
